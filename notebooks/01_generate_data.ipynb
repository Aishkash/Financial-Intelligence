# %%
import pandas as pd
import numpy as np

# %%
import sys
import os

# Add backend to Python path
sys.path.append(os.path.abspath(".."))

from backend.app.features.feature_engineering import generate_features

# %%
np.random.seed(42)

n = 5000

df = pd.DataFrame({
    "transaction_id": range(n),
    "user_id": np.random.randint(1, 500, n),
    "amount": np.random.exponential(scale=2000, size=n),
    "timestamp": pd.date_range("2024-01-01", periods=n, freq="min"),
    "device_id": np.random.randint(1, 300, n),
    "location": np.random.randint(1, 50, n),
})

df.to_csv("../data/raw/transactions.csv", index=False)
df.head()
# Out:
#    transaction_id  user_id       amount           timestamp  device_id  \
# 0               0      103  1850.123652 2024-01-01 00:00:00        125
# 1               1      436   885.754857 2024-01-01 00:01:00         59
# 2               2      349  2087.211237 2024-01-01 00:02:00         97
# 3               3      271   262.315689 2024-01-01 00:03:00        275
# 4               4      107  4390.316871 2024-01-01 00:04:00        149
#
#    location
# 0        30
# 1         8
# 2        31
# 3        48
# 4        47

# %%
df = generate_features(df)
df.head()
# Out:
#    transaction_id  user_id       amount           timestamp  device_id  \
# 0               0      103  1850.123652 2024-01-01 00:00:00        125
# 1               1      436   885.754857 2024-01-01 00:01:00         59
# 2               2      349  2087.211237 2024-01-01 00:02:00         97
# 3               3      271   262.315689 2024-01-01 00:03:00        275
# 4               4      107  4390.316871 2024-01-01 00:04:00        149
#
#    location  hour  day_of_week  time_since_last_txn  user_avg_amount  \
# 0        30     0            0                  0.0      2318.075307
# 1         8     0            0                  0.0      1424.276030
# 2        31     0            0                  0.0      1207.436270
# 3        48     0            0                  0.0       949.501639
# 4        47     0            0                  0.0      2041.435356
#
#    user_std_amount  amount_deviation
# 0      2728.839073         -0.171421
# 1      2152.581617         -0.250058
# ...

# %%
df["is_fraud"] = (
    (df["amount_deviation"] > 3) |
    (df["time_since_last_txn"] < 10)
).astype(int)

# %%
df.to_csv("../data/processed/transactions_with_features.csv", index=False)
